# %% [markdown]
# # Single Linked List

# %% [markdown]
# ## algorithm

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        
    # add to ll's head
    def add(self, data):
        node = Node(data)
        if self.head == None :
            self.head = node
        else:
            node.next = self.head
            self.head = node
            
    # remove ll's head
    def remove(self):
        if self.head != None :
            tmp = self.head
            self.head = tmp.next
            
    def search(self, k):
        p = self.head
        while p != None :
            if p.data == k :
                return p
            p = p.next
        return None
    
    def __str__(self) :
        s = ""
        p = self.head
        while p != None :
            s += p.data + ' '
            p = p.next
        return s

# %% [markdown]
# ## run

# %%
ll = LinkedList()

ll.add( 'a' )
ll.add( 'b' )
ll.add( 'c' )

print ll
ll.remove()
print ll
ll.remove()
print ll
# Out:
# c b a
# b a
# a

# %% [markdown]
# # Double Linked List

# %% [markdown]
# ## algorithm

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class LinkedList:
    def __init__(self):
        self.head = None
        
    # add to ll's head
    def add(self, data):
        node = Node(data)
        if self.head == None :
            self.head = node
        else:
            node.next = self.head
            node.next.prev = node
            self.head = node
            
    # remove node p in ll
    def remove(self, p):
        if p == self.head :
            self.head = p.next
        else:
            tmp = p.prev
            tmp.next = p.next
            if tmp.next != None :
                tmp.next.prev = tmp
        
    def search(self, k):
        p = self.head
        while p != None :
            if p.data == k :
                return p
            p = p.next
        return None
    
    def __str__(self) :
        s = ""
        p = self.head
        while p != None :
            s += p.data + ' '
            p = p.next
        return s

# %% [markdown]
# ## run

# %%
ll = LinkedList()

ll.add( 'a' )
ll.add( 'b' )
ll.add( 'c' )

print ll
ll.remove( ll.search( 'b' ) )
print ll
ll.remove( ll.search( 'c' ) )
print ll
ll.remove( ll.search( 'a' ) )
print ll
# Out:
# c b a
# c a
# a
